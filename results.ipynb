# %%
from datasets import Dataset
from IPython.core.getipython import get_ipython
from peft import AutoPeftModelForCausalLM
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, BitsAndBytesConfig, pipeline
import Levenshtein
import pandas as pd
import torch

# %%
# Compute character error rate (CER)
def cer(prediction, target):
    distance = Levenshtein.distance(prediction, target)
    return distance / len(target)

# Helper function to store results as a CSV
def get_results(data, preds):
    results = data.to_pandas()
    results['Model Correction'] = preds
    results = results.rename(columns={'CER': 'old_CER'})
    results['new_CER'] = results.apply(lambda row: cer(row['Model Correction'], row['Ground Truth']), axis=1)
    results['CER_reduction'] = ((results['old_CER'] - results['new_CER']) / results['old_CER']) * 100
    return results

# %% [markdown]
# ## BART

# %% [markdown]
# Generate post-OCR corrections with BART and save to `results` folder of the project.

# %%
model_dir = 'pykale/bart-large-ocr'

test = pd.read_csv('data/test.csv')
test = Dataset.from_pandas(test)

model = AutoModelForSeq2SeqLM.from_pretrained(model_dir)
tokenizer = AutoTokenizer.from_pretrained(model_dir)
generator = pipeline('text2text-generation', model=model.to('cuda'), tokenizer=tokenizer, device='cuda', max_length=1024)

preds = []
for sample in tqdm(test):
    preds.append(generator(sample['OCR Text'])[0]['generated_text'])

results = get_results(test, preds)
results.to_csv('results/bart-large.csv', index=False)

# %% [markdown]
# ## Llama 2

# %% [markdown]
# Generate post-OCR corrections with Llama 2 and save to `results` folder of the project.

# %%
model_dir = 'pykale/llama-2-13b-ocr'

test = pd.read_csv('data/test.csv')
test = Dataset.from_pandas(test)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_compute_dtype=torch.bfloat16,
)

model = AutoPeftModelForCausalLM.from_pretrained(
    model_dir,
    quantization_config=bnb_config,
    low_cpu_mem_usage=True,
    torch_dtype=torch.float16,
)
tokenizer = AutoTokenizer.from_pretrained(model_dir)

i = 0
preds = []

cell = '''
prompt = f"""### Instruction:
Fix the OCR errors in the provided text.

### Input:
{test[i]['OCR Text']}

### Response:
"""

input_ids = tokenizer(prompt, max_length=1024, return_tensors='pt', truncation=True).input_ids.cuda()
with torch.inference_mode():
    outputs = model.generate(input_ids=input_ids, max_new_tokens=1024, do_sample=True, temperature=0.7, top_p=0.1, top_k=40)
pred = tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0][len(prompt):].strip()
preds.append(pred)
i += 1
'''

ipython = get_ipython()
for _ in tqdm(range(len(test))):
    ipython.run_cell(cell)

results = get_results(test, preds)
results.to_csv('results/llama-2-13b.csv', index=False)

# %% [markdown]
# ## Corrections

# %% [markdown]
# Examine post-OCR corrections of a given model on the test set.

# %%
results = {'bart-base': pd.read_csv('results/bart-base.csv'),
           'bart-large': pd.read_csv('results/bart-large.csv'),
           'llama-2-7b': pd.read_csv('results/llama-2-7b.csv'),
           'llama-2-13b': pd.read_csv('results/llama-2-13b.csv')}

corrections = results['llama-2-13b']
corrections.head(10)
# Out:
#     Sample ID        Date              Publication  \
# 0  3200797032  1882-05-27  Illustrated Police News
# 1  3200797032  1882-05-27  Illustrated Police News
# 2  3200797032  1882-05-27  Illustrated Police News
# 3  3200797032  1882-05-27  Illustrated Police News
# 4  3200797032  1882-05-27  Illustrated Police News
# 5  3200797032  1882-05-27  Illustrated Police News
# 6  3200797032  1882-05-27  Illustrated Police News
# 7  3200797032  1882-05-27  Illustrated Police News
# 8  3200797032  1882-05-27  Illustrated Police News
# 9  3200797032  1882-05-27  Illustrated Police News
#
#                                             OCR Text  \
# 0                 CHARGE OF SETTING FIRE TO A HOUSE.
# 1  AT the Thames police-eourt, Charles Mawzi was ...
# 2  At a quarter to four o'clock that 'c�morniink ...
# 3  *Lilly caught hold of him, 'ai found that his ...
# 4  On reaclhing No. 2, whiG1e is an unoc6njid 'ao...
# 5  He iqrihng his rattle, and William Gadd, sorge...
# 6  Ford got in the windoxw, and on opening the ba...
# 7  Lilly ran for the turnuock, and in the meantim...
# 8  In ten minutes' time a fire engine arrived, an...
# 9     The prisoner said he 'ent to put out the fire,
#
#                                         Ground Truth   old_CER  \
# 0                 CHARGE OF SETTING FIRE TO A HOUSE.  0.000000
# 1  AT the Thames police-court, Charles Mawzi was ...  0.019737
# 2  At a quarter to four o'clock that morning Lill...  0.105611
# 3  Lilly caught hold of him, and found that his c...  0.113990
# 4  On reaching No. 2, which is an unoccupied hous...  0.107784
# 5  He sprang his rattle, and William Gadd, sergea...  0.090909
# 6  Ford got in the window, and on opening the bac...  0.055944
# 7  Lilly ran for the turncock, and in the meantim...  0.076087
# 8  In ten minutes' time a fire engine arrived, an...  0.073770
# 9     The prisoner said he went to put out the fire.  0.043478
#
#                                     Model Correction   new_CER  CER_reduction
# 0                 CHARGE OF SETTING FIRE TO A HOUSE.  0.000000            NaN
# 1  AT the Thames police-court, Charles Mawzi was ...  0.006579      66.666667
# 2  At a quarter to four o'clock that morning Lill...  0.009901      90.625000
# 3  Lilly caught hold of him, and found that his c...  0.000000     100.000000
# 4  On reaching No. 2, which is an unoccupied hous...  0.000000     100.000000
# 5  He was crying his rattle, and William Gadd, se...  0.068182      25.000000
# 6  Ford got in the window, and on opening the bac...  0.000000     100.000000
# 7  Lilly ran for the turncock, and in the meantim...  0.016304      78.571429
# 8  In ten minutes' time a fire engine arrived, an...  0.000000     100.000000
# 9     The prisoner said he went to put out the fire.  0.000000     100.000000

# %%
for i in range(len(corrections)):
    print(i+1)
    print(f"OCR Text:\n{corrections['OCR Text'][i]}\n")
    print(f"Ground Truth:\n{corrections['Ground Truth'][i]}\n")
    print(f"Model Correction:\n{corrections['Model Correction'][i]}\n\n")
# Out:
# 1
# OCR Text:
# CHARGE OF SETTING FIRE TO A HOUSE.
#
# Ground Truth:
# CHARGE OF SETTING FIRE TO A HOUSE.
#
# Model Correction:
# CHARGE OF SETTING FIRE TO A HOUSE.
#
#
# 2
# OCR Text:
# AT the Thames police-eourt, Charles Mawzi was charged with wilfully and maliciously setting fire to the house, 2 Caroline-9treet, Commercial-road East.
#
# Ground Truth:
# AT the Thames police-court, Charles Mawzi was charged with willfully and maliciously setting fire to the house, 2 Caroline-street, Commercial-road East.
#
# Model Correction:
# AT the Thames police-court, Charles Mawzi was charged with wilfully and maliciously setting fire to the house, 2 Caroline-street, Commercial-road East.
#
#
# 3
# OCR Text:
# At a quarter to four o'clock that 'c�morniink Lilly, a constable, No. 332 E, wias'oh datyin Carblind-stc'eet, . when he met the prisoeer, and he said, "I hive just come from ,afire," alluclingtoaiconflagration in.Philpot- street, Commercial-rbad, " and therb is anotlher one up the street, close to the brewery."
#
# Ground Truth:
# At a quarter to four o'clock that morning Lilly, a constable, No. 332 K, was on duty in Caroline-street, when he met the prisoner, and he said, "I have just come from a fire," alluding to a conflagration in Philpot-street, Commercial-road, "and there is another one up the street, close to the brewery."
#
# Model Correction:
# At a quarter to four o'clock that morning Lilly, a constable, No. 332 E, was on duty in Carblind-street, when he met the prisoner, and he said, "I have just come from a fire," alluding to a conflagration in Philpot-street, Commercial-road, "and there is another one up the street, close to the brewery."
#
#
# 4
# OCR Text:
# *Lilly caught hold of him, 'ai found that his coat snd hands were dovered with vwhiteivash, and on being dsl'ed to -acoiant for it he said, " I have~jdst tome fronm a ire; I'll show you where it is."
#
# Ground Truth:
# Lilly caught hold of him, and found that his coat and hands were covered with whitewash, and on being asked to account for it he said, "I have just come from a fire; I'll show you where it is."
#
# Model Correction:
# Lilly caught hold of him, and found that his coat and hands were covered with whitewash, and on being asked to account for it he said, "I have just come from a fire; I'll show you where it is."
#
#
# 5
# OCR Text:
# On reaclhing No. 2, whiG1e is an unoc6njid 'aouse, prisoner pulled open tLie shitters and said, "Can't you hear the fire now 1" and Lilly then heard the craulding of wood.
#
# Ground Truth:
# On reaching No. 2, which is an unoccupied house, prisoner pulled open the shutters and said, "Can't you hear the fire now?" and Lilly then heard the crackling of wood.
#
# Model Correction:
# On reaching No. 2, which is an unoccupied house, prisoner pulled open the shutters and said, "Can't you hear the fire now?" and Lilly then heard the crackling of wood.
#
#
# 6
# OCR Text:
# He iqrihng his rattle, and William Gadd, sorgeant, 23 H, and Alfred Ford, .358 K, caine up.
#
# Ground Truth:
# He sprang his rattle, and William Gadd, sergeant, 23 H, and Alfred Ford, 358 K, came up.
#
# Model Correction:
# He was crying his rattle, and William Gadd, sergeant, 23 H, and Alfred Ford, 358 K, came up.
#
#
# 7
# OCR Text:
# Ford got in the windoxw, and on opening the back parlour door he found the stair- ease ia flsmes; also the ground and basement floor partly bnrgt.
#
# Ground Truth:
# Ford got in the window, and on opening the back parlour door he found the staircase in flames; also the ground and basement floor partly burnt.
#
# Model Correction:
# Ford got in the window, and on opening the back parlour door he found the staircase in flames; also the ground and basement floor partly burnt.
#
#
# 8
# OCR Text:
# Lilly ran for the turnuock, and in the meantime Srgeant Ghdd end Ford, eassisted by a ran with a hose in the Commercial f3 ewery, next door to the house, commened ;liyihg on the fire.
#
# Ground Truth:
# Lilly ran for the turncock, and in the meantime Sergeant Gadd and Ford, assisted by a man with a house in the Commercial Brewery, next door to the house, commenced playing on the fire.
#
# Model Correction:
# Lilly ran for the turncock, and in the meantime Sergeant Godd and Ford, assisted by a man with a hose in the Commercial brewery, next door to the house, commenced playing on the fire.
#
#
# 9
# OCR Text:
# In ten minutes' time a fire engine arrived, and the flanes were extinguished Sac~geant Gadd gave tle prisoner into cestoif .
#
# Ground Truth:
# In ten minutes' time a fire engine arrived, and the flames were extinguished Sergeant Gadd gave the prisoner into custody.
#
# Model Correction:
# In ten minutes' time a fire engine arrived, and the flames were extinguished Sergeant Gadd gave the prisoner into custody.
#
#
# 10
# OCR Text:
# The prisoner said he 'ent to put out the fire,
#
# Ground Truth:
# The prisoner said he went to put out the fire.
#
# Model Correction:
# The prisoner said he went to put out the fire.
#
#
# 11
# OCR Text:
# He was remanded, one surety in �20 being accepted for his appearance.
#
# Ground Truth:
# He was remanded, one surety in £20 being accepted for his appearance.
#
# Model Correction:
# He was remanded, one surety in £20 being accepted for his appearance.
#
#
# 12
# OCR Text:
# CAPTURE OF PICKPOCKETS.
#
# Ground Truth:
# CAPTURE OF PICKPOCKETS.
#
# Model Correction:
# CAPTURE OF PICKPOCKETS.
#
#
# 13
# OCR Text:
# AT Stratford petty sessions, Henry Harcourt, twenty- five, a waiter and deafer, of Victorsa-park; and Micliasl Higgins, living at a lodging-house in Commercial- strmet, were charged with stealing a sum of �5 from Joseph Samuel Smith, residing at Higham.street, Walthamstow ; Henry Wallace Zaddres fused) was also charged with being concerned with the others, and also with assaulting Henry Thomas by striking him with a stone.
#
# Ground Truth:
# AT Stratford petty sessions, Henry Harcourt, twenty-five, a waiter and dealer, of Victoria-park; and Michael Higgins, living at a lodging-house in Commercial-street, were charged with stealing a sum of £5 from Joseph Samuel Smith, residing at Higham-street, Walthamstow; Henry Wallace (address refused) was also charged with being concerned with the others, and also with assaulting Henry Thomas by striking him with a stone.
#
# Model Correction:
# AT Stratford petty sessions, Henry Harcourt, twenty-five, a waiter and dealer, of Victoria-park; and Michael Higgins, living at a lodging-house in Commercial-street, were charged with stealing a sum of £5 from Joseph Samuel Smith, residing at Higham-street, Walthamstow; Henry Wallace Zaddres, forty-five, was also charged with being concerned with the others, and also with assaulting Henry Thomas by striking him with a stone.
#
#
# 14
# OCR Text:
# Police-constablo 216 A stated that he was near Higham-hill Dairy Farm, where a sale was . taking place, and he saw the prisoners standing round the prosecutor.
#
# Ground Truth:
# Police-constable 216 A stated that he was near Higham-hill Dairy Farm, where a sale was taking place, and he saw the prisoners standing round the prosecutor.
#
# Model Correction:
# Police-constable 216 A stated that he was near Higham-hill Dairy Farm, where a sale was taking place, and he saw the prisoners standing round the prosecutor.
#
#
# 15
# OCR Text:
# He further sawr Henry Wallace taking his hand from the prosecutor's lefthand trousers pocket.
#
# Ground Truth:
# He further saw Henry Wallace taking his hands from the prosecutor's lefthand trousers pocket.
#
# Model Correction:
# He further saw Henry Wallace taking his hand from the prosecutor's left-hand trousers pocket.
#
#
# 16
# OCR Text:
# Witness then went to Mr. Smith, and that gentleman discovered he had lost a bag, in which was �5.
#
# Ground Truth:
# Witness then went to Mr. Smith, and that gentleman discovered he had lost a bag, in which was £5.
#
# Model Correction:
# Witness then went to Mr. Smith, and that gentleman discovered he had lost a bag, in which was £5.
#
#
# 17
# OCR Text:
# The prisoners were seen running down the hill together, and after a smart chase they were captured, tio by the officer and Harcourt by a gentleman in a trap.
#
# Ground Truth:
# The prisoners were seen running down the hill together, and after a smart chase they were captured, two by the officer and Harcourt by a gentleman in a trap.
#
# Model Correction:
# The prisoners were seen running down the hill together, and after a smart chase they were captured, one by the officer and Harcourt by a gentleman in a trap.
#
#
# 18
# OCR Text:
# The officer saw money passed between the pri. soners, and wheunat the station �2 58. 1Add. was found upon them. A warder from Coidbath-fields prison proved previous convictions against Wallace.
#
# Ground Truth:
# The officer saw money passed between the prisoners, and when at the station £2 5s. 10 ½d. was found upon them A warder from Coldbath-fields prison proved previous convictions against Wallace.
#
# Model Correction:
# The officer saw money passed between the prisoners, and when at the station £2 5s. 6d. was found upon them. A warder from Coldbath-fields prison proved previous convictions against Wallace.
#
#
# 19
# OCR Text:
# They were committed for trial.
#
# Ground Truth:
# They were committed for trial.
#
# Model Correction:
# They were committed for trial.
#
#
# 20
# OCR Text:
# CRUELTY TO A RACE HonsE.
#
# Ground Truth:
# CRUELTY TO A RACE HORSE.
#
# Model Correction:
# CRUELTY TO A RACE HORSE.
#
#
# 21
# OCR Text:
# - Mr. Litberes, the well.known gentleman rider at steeplechases, was on Saturday summoned before the Crewkerne magistrates, at the instance of the Society for the Prevention of Cruelty to Animals, for ill-treating a horse by over. spurring it at the West Somerset Steeplechases in March.
#
# Ground Truth:
# – Mr. Litherea, the well-known gentleman rider at steeplechases, was on Saturday summoned before the Crewkerne magistrates, at the instance of the Society for the Prevention of Cruelty to Animals, for ill-treating a horse by over-spurring it at the West Somerset Steeplechases in March.
#
# Model Correction:
# -Mr. Liberals, the well-known gentleman rider at steeplechases, was on Saturday summoned before the Crewkerne magistrates, at the instance of the Society for the Prevention of Cruelty to Animals, for ill-treating a horse by over-spurring it at the West Somerset Steeplechases in March.
#
#
# 22
# OCR Text:
# The defence was, that the injuries were caused by the horse cannoning against the rail.
#
# Ground Truth:
# The defence was, that the injuries were caused by the horse cannoning against the rail.
#
# Model Correction:
# The defence was, that the injuries were caused by the horse cannoning against the rail.
#
#
# 23
# OCR Text:
# The defendant wits'fined �5 and costs.
#
# Ground Truth:
# The defendant was fined £5 and costs.
#
# Model Correction:
# The defendant was fined £5 and costs.
#
#
# 24
# OCR Text:
# REMARKABLE SUICIDE NEAR PLYBIOUTH.
#
# Ground Truth:
# REMARKABLE SUICIDE NEAR PLYMOUTH.
#
# Model Correction:
# REMARKABLE SUICIDE NEAR PLYMOUTH.
#
#
# 25
# OCR Text:
# -Whilst a goods train was passing over the tubular bridge on, the Corfveall Railway, at Saltash, on Saturday night, thedrioernoticed a nman deliberately place hiniself in front of the engine.
#
# Ground Truth:
# – Whilst a goods train was passing over the tubular bridge on the Cornwall Railway, at Saltash, on Saturday night, the driver noticed a man deliberately place himself in front of the engine.
#
# Model Correction:
# -Whilst a goods train was passing over the tubular bridge on the Cornwall Railway, at Saltash, on Saturday night, the driver noticed a man deliberately place himself in front of the engine.
#
#
# 26
# OCR Text:
# The whistle was blown and the. * brake fplied, but before the train could be brought up it had passed over the man, who was terribly mangled.i
#
# Ground Truth:
# The whistle was blown and the brake applied, but before the train could be brought up it had passed over the man, who was terribly mangled.
#
# Model Correction:
# The whistle was blown and the brake applied, but before the train could be brought up it had passed over the man, who was terribly mangled.
#
#
# 27
# OCR Text:
# In his pocket was found a letter addressed to his wife, irs. Purvis, of Plymouth, intimating his resolve to commit suicide.
#
# Ground Truth:
# In his pocket was a found a letter addressed to his wife, Mrs. Purvis, of Plymouth, intimating his resolve to commit suicide.
#
# Model Correction:
# In his pocket was found a letter addressed to his wife, Mrs. Purvis, of Plymouth, intimating his resolve to commit suicide.
#
#
# 28
# OCR Text:
# THE RtNc TnEXTRi TnIAL-SEVERE SENTENCES.
#
# Ground Truth:
# THE RING THEATRE TRIAL. --- SEVERE SENTENCES.
#
# Model Correction:
# THE RUNAWAY TRIAL-SEVERE SENTENCES.
#
#
# 29
# OCR Text:
# -The decision of the court in the case of the fire at the Ring Theatre Was delivered last week at Vienna.
#
# Ground Truth:
# – The decision of the court in the case of the fire at the Ring Theatre was delivered last week at Vienna.
#
# Model Correction:
# -The decision of the court in the case of the fire at the Ring Theatre was delivered last week at Vienna.
#
#
# 30
# OCR Text:
# Herr Jauner, manager of the theatre, the workman Nitsbhe, and Inspeotor Geringer, were pronounced guilty of contributing to the catastrophe by their negligence.
#
# Ground Truth:
# Herr Jauuer, manager of the theatre, the workman Nitsche, and Inspector Geringer, were pronounced guilty of contributing to the catastrophe by their negligence.
#
# Model Correction:
# Herr Jauner, manager of the theatre, the workman Nitshe, and Inspector Geringer, were pronounced guilty of contributing to the catastrophe by their negligence.
#
#
# 31
# OCR Text:
# The first-named was sentenced to four months simple arrest, Inspector Geringer to strict im- prisonment for the same period, and Nitsche to eight months' imprisonment.
#
# Ground Truth:
# The first-named was sentenced to four months simple arrest, Inspector Geringer to strict imprisonment for the same period, and Nitsche to eight months' imprisonment.
#
# Model Correction:
# The first-named was sentenced to four months' simple imprisonment, Inspector Geringer to strict imprisonment for the same period, and Nitsche to eight months' imprisonment.
#
#
# 32
# OCR Text:
# In the two last cases an addi. tional punishment is inflicted of one fasting day a month.
#
# Ground Truth:
# In the two last cases and additional punishment is inflicted of one fasting day a month.
#
# Model Correction:
# In the two last cases an additional punishment is inflicted of one fasting day a month.
#
#
# 33
# OCR Text:
# The other defendants were acquitted.
#
# Ground Truth:
# The other defendants were acquitted.
#
# Model Correction:
# The other defendants were acquitted.
#
#
# 34
# OCR Text:
# DOUBLE MURDER BY A MOTHER AT | I P9,USHOLMIE.
#
# Ground Truth:
# DOUBLE MURDER BY A MOTHER AT RUSHOLME.
#
# Model Correction:
# DOUBLE MURDER BY A MOTHER AT PUSHINGTON.
#
#
# 35
# OCR Text:
# i [SUBJECT OF ILLUSTRATION.]
#
# Ground Truth:
# [SUBJECT OF ILLUSTRATION.]
#
# Model Correction:
# [SUBJECT OF ILLUSTRATION.]
#
#
# 36
# OCR Text:
# 't, ABOUT noon on Friday information was received at en the Rusholme Police-station that a woman had mur. 2, dered her two children, aged three and five respectively, | th and then attempted to commit suicide by drowning.
#
# Ground Truth:
# ABOUT noon on Friday information was received at the Rusholme Police-station that a woman had murdered her two children, aged three and five respectively, and then attempted to commit suicide by drowning.
#
# Model Correction:
# ABOUT noon on Friday information was received at the Rusholme Police-station that a woman had murdered her two children, aged three and five respectively, and then attempted to commit suicide by drowning.
#
#
# 37
# OCR Text:
# th Upon the information being received Inspector Smithj an went at once with the person who gave the information g- to No. 54, Moss-side.
#
# Ground Truth:
# Upon the information being received Inspector Smith went at once with the person who gave the information to No. 54, Moss-side.
#
# Model Correction:
# Upon the information being received Inspector Smith went at once with the person who gave the information to No. 54, Moss-side.
#
#
# 38
# OCR Text:
# On making a detailed examina- o- tion of the premises he found the two children lying rt on a bed in one of the bedrooms naked and quite dead, p. apparently from drowning.
#
# Ground Truth:
# On making a detailed examination of the premises he found the two children lying on a bed in one of the bedrooms naked and quite dead, apparently from drowning.
#
# Model Correction:
# On making a detailed examination of the premises he found the two children lying on a bed in one of the bedrooms naked and quite dead, apparently from drowning.
#
#
# 39
# OCR Text:
# Upon the body of one of rt the children there was a piece of paper containing in some almost illegible writing.
#
# Ground Truth:
# Upon the body of one of the children there was a piece of paper containing some almost illegible writing.
#
# Model Correction:
# Upon the body of one of the children there was a piece of paper containing in some almost illegible writing.
#
#
# 40
# OCR Text:
# What portions of it al that could be made out ran as follows :-" Dear Papa, in -I could not stand it any longer . . . . to you. e. I do not think they are dead, for they a . We se shall never meet in heaven, I could not help it. I as had a good husband. '
#
# Ground Truth:
# What portions of it that could be made out rang as follows :-- "Dear Papa, -- I could not stand it any longer . . . . to you. I do not think they are dead, for they . . . We shall never meet in heaven. I could not help it. I had a good husband."
#
# Model Correction:
# What portions of it could be made out ran as follows: - "Dear Papa, in I could not stand it any longer. I am going to you. I do not think they are dead, for they a. We shall never meet in heaven, I could not help it. I had a good husband."
#
#
# 41
# OCR Text:
# The inspector took Mrs. Ifib. as bert to the Rusholme Police-station, where she now md lies,
#
# Ground Truth:
# The inspector took Mrs. Hibbert to the Rusholme Police-station, where she now lies.
#
# Model Correction:
# The inspector took Mrs. Hubbard as prisoner to the Rusholme Police-station, where she now lies.
#
#
# 42
# OCR Text:
# The full circumstances of the case appear to ig be as follows :-The unfortunate woman is the wife a, of jThomras Hibbert, joiner and builder.
#
# Ground Truth:
# The full circumstances of the case appear to be as follows: -- The unfortunate woman is the wife of Thomas Hibbert, joiner and builder.
#
# Model Correction:
# The full circumstances of the case appear to be as follows: -The unfortunate woman is the wife of Thomas Hibbert, joiner and builder.
#
#
# 43
# OCR Text:
# About at twelve months ago Mrs. Hlibbert gave birth to w a child,
#
# Ground Truth:
# About twelve months ago Mrs. Hibbert gave birth to a child.
#
# Model Correction:
# About a twelve months ago Mrs. Hibbert gave birth to a child.
#
#
# 44
# OCR Text:
# She fell ill, and finally became insane,
#
# Ground Truth:
# She fell ill, and finally became insane.
#
# Model Correction:
# She fell ill, and finally became insane.
#
#
# 45
# OCR Text:
# She n was removed to the Parkfield Asyloam, near Maccles- r, field, of which institution she was an inmate up till y the 3rd of this month.
#
# Ground Truth:
# She was removed to the Parkfield Asylum, near Macclesfield, of which institution she was an inmate up till the 3rd of this month.
#
# Model Correction:
# She was removed to the Parkfield Asylum, near Macclesfield, of which institution she was an inmate up till the 3rd of this month.
#
#
# 46
# OCR Text:
# On that day her husband took l her home, although warned that she was not perfectly :o sane, and that a strict watch would have to be kept le over her actions.
#
# Ground Truth:
# On that day her husband took her home, although warned that she was not perfectly sane, and that a strict watch would have to be kept over her actions.
#
# Model Correction:
# On that day her husband took her home, although warned that she was not perfectly sane, and that a strict watch would have to be kept over her actions.
#
#
# 47
# OCR Text:
# He proposed to hire a nurse, but l0 Mrs. Hibbert appeared to be very much upset at such a a notion being entertained that the idea was abandoned.
#
# Ground Truth:
# He proposed to hire a nurse, but Mrs. Hibbert appeared to be very much upset at such a notion being entertained that the idea was abandoned.
#
# Model Correction:
# He proposed to hire a nurse, but Mrs. Hibbert appeared to be very much upset at such a notion being entertained, and the idea was abandoned.
#
#
# 48
# OCR Text:
# is On Friday morning he left for work as usual, leaving f 3. instructions for the servant to look after his wife.
#
# Ground Truth:
# On Friday morning he left for work as usual, leaving instructions for the servant to look after his wife.
#
# Model Correction:
# On Friday morning he left for work as usual, leaving instructions for the servant to look after his wife.
#
#
# 49
# OCR Text:
# 2 .s Shortly after his departure Airs. Hibbert called the d s children upstairs to her, and was upstairs for about t is half an hour.
#
# Ground Truth:
# Shortly after his departure Mrs. Hibbert called the children upstairs to her, and was upstairs for about half an hour.
#
# Model Correction:
# Shortly after his departure Mrs. Hibbert called the children upstairs to her, and was upstairs for about half an hour.
#
#
# 50
# OCR Text:
# She came down looking very ill,
#
# Ground Truth:
# She came down looking very ill.
#
# Model Correction:
# She came down looking very ill.
#
#
# 51
# OCR Text:
# The s a servant became alarmed, and called in a neighbour.
#
# Ground Truth:
# The servant became alarmed, and called in a neighbour.
#
# Model Correction:
# The servant became alarmed, and called in a neighbour.
#
#
# 52
# OCR Text:
# n They went upstairs and heard a splashing in the bath.
#
# Ground Truth:
# They went upstairs and heard a splashing in the bath.
#
# Model Correction:
# They went upstairs and heard a splashing in the bath.
#
#
# 53
# OCR Text:
# c o They went into the room andi found Mrs. Hibbert in i the bath.
#
# Ground Truth:
# They went into the room and found Mrs. Hibbert in the bath.
#
# Model Correction:
# They went into the room and found Mrs. Hibbert in the bath.
#
#
# 54
# OCR Text:
# She then told them the two children were a eInptairs, but. sshe did not thihsni they were dead,
#
# Ground Truth:
# She then told them the two children were upstairs, but she did not think they were dead.
#
# Model Correction:
# She then told them the two children were asleep, but she did not think they were dead.
#
#
# 55
# OCR Text:
# She - J also told them she had been trying to drown herself.
#
# Ground Truth:
# She also told them she had been trying to drown herself.
#
# Model Correction:
# She also told them she had been trying to drown herself.
#
#
# 56
# OCR Text:
# kThey at once went and gave information to the police.
#
# Ground Truth:
# They at once went and gave information to the police.
#
# Model Correction:
# They at once went and gave information to the police.
#
#
# 57
# OCR Text:
# t e .LATER DETAILS,
#
# Ground Truth:
# LATER DETAILS.
#
# Model Correction:
# LATER DETAILS.
#
#
# 58
# OCR Text:
# d Upon farther inquiries being made, the following C details were ascertained.
#
# Ground Truth:
# Upon further inquiries being made, the following details were ascertained.
#
# Model Correction:
# Upon farther inquiries being made, the following details were ascertained.
#
#
# 59
# OCR Text:
# About a year ago Mrs. t Hibbert was confined of a child,
#
# Ground Truth:
# About a year ago Mrs. Hibbert was confined of a child.
#
# Model Correction:
# About a year ago Mrs. Hibbert was confined of a child.
#
#
# 60
# OCR Text:
# The week following tI she fell ill, ultimately becoming insane, necessitating t her removal to the Parkfield Asylum, Macelesfield.
#
# Ground Truth:
# The week following she fell ill, ultimately becoming insane, necessitating her removal to the Parkfield Asylum, Macclesfield.
#
# Model Correction:
# The week following she fell ill, ultimately becoming insane, necessitating her removal to the Parkfield Asylum, Macclesfield.
#
#
# 61
# OCR Text:
# t She was detained in that institution until Wednesday, when she was taken out by her husband.
#
# Ground Truth:
# She was detained in that institution until Wednesday, when she was taken out by her husband.
#
# Model Correction:
# She was detained in that institution until Wednesday, when she was taken out by her husband.
#
#
# 62
# OCR Text:
# He was told she was not perfectly convalescent.
#
# Ground Truth:
# He was told she was not perfectly convalescent.
#
# Model Correction:
# He was told she was not perfectly convalescent.
#
#
# 63
# OCR Text:
# He. stated his intention of providing a nurse for her, but that seemedn to excite Mrs. Hibbert to such an extent that the idea e was reluctantly abandoned.
#
# Ground Truth:
# He stated his intention of providing a nurse for her, but that seemed to excite Mrs. Hibbert to such an extent that the idea was reluctantly abandoned.
#
# Model Correction:
# He stated his intention of providing a nurse for her, but that seemed to excite Mrs. Hibbert to such an extent that the idea was reluctantly abandoned.
#
#
# 64
# OCR Text:
# Mrs. Hibbert rose about Si half past seven on Friday morning and had breakfast b with her husband.
#
# Ground Truth:
# Mrs. Hibbert rose about half-past seven on Friday morning and had breakfast with her husband.
#
# Model Correction:
# Mrs. Hibbert rose about half past seven on Friday morning and had breakfast with her husband.
#
#
# 65
# OCR Text:
# She then appeared to be in her usual health, bodily and mentally.
#
# Ground Truth:
# She then appeared to be in her usual health, bodily and mentally.
#
# Model Correction:
# She then appeared to be in her usual health, bodily and mentally.
#
#
# 66
# OCR Text:
# M1r. Hibbert l'eft a the house about eight o'clock in order to proceed to his uN work, but prior to his doing so he gave strict orders to his servant to keep an eye upon her mistress's move- ments.
#
# Ground Truth:
# Mr. Hibbert left the house about eight o'clock in order to proceed to his work, but prior to his doing so he gave strict orders to his servant to keep an eye upon her mistress's movements.
#
# Model Correction:
# Mr. Hibbert left the house about eight o'clock in order to proceed to his work, but prior to his doing so he gave strict orders to his servant to keep an eye upon her mistress's movements.
#
#
# 67
# OCR Text:
# About nine o'clock Mrs. Hibbert told the servant to call the children in from playing in the front vi garden.
#
# Ground Truth:
# About nine o'clock Mrs. Hibbert told the servant to call the children in from playing in the front garden.
#
# Model Correction:
# About nine o'clock Mrs. Hibbert told the servant to call the children in from playing in the front garden.
#
#
# 68
# OCR Text:
# Mrs. Hibbert took hold of the children and C took them upstairs with her.
#
# Ground Truth:
# Mrs. Hibbert took hold of the children and took them upstairs with her.
#
# Model Correction:
# Mrs. Hibbert took hold of the children and took them upstairs with her.
#
#
# 69
# OCR Text:
# She came down shortly 6* afterwards and sent the servant for a bottle of soda, a saying that she felt very unwell.
#
# Ground Truth:
# She came down shortly afterwards and sent the servant for a bottle of soda, saying that she felt very unwell.
#
# Model Correction:
# She came down shortly afterwards and sent the servant for a bottle of soda, saying that she felt very unwell.
#
#
# 70
# OCR Text:
# On the servant's a! return with the soda water, she asked her mistress what P had become of the children.
#
# Ground Truth:
# On the servant's return with the soda water, she asked her mistress what had become of the children.
#
# Model Correction:
# On the servant's return with the soda water, she asked her mistress what had become of the children.
#
#
# 71
# OCR Text:
# Mrs. Hibbert replied that they had gone to the corner shop.
#
# Ground Truth:
# Mrs. Hibbert replied that they had gone to the corner shop.
#
# Model Correction:
# Mrs. Hibbert replied that they had gone to the corner shop.
#
#
# 72
# OCR Text:
# The servant went of to inquire if they were there, but was told they had never been there.
#
# Ground Truth:
# The servant went to inquire if they were there, but was told they had never been there.
#
# Model Correction:
# The servant went out to inquire if they were there, but was told they had never been there.
#
#
# 73
# OCR Text:
# Becoming alarmed,/she procured a I neighbour named Mrs. Deedle to go back to the house t with her, as she suspected something was the matter.
#
# Ground Truth:
# Becoming alarmed, she procured a neighbour named Mrs. Deedle to go back to the house with her, as she suspected something was the matter.
#
# Model Correction:
# Becoming alarmed, she procured a neighbour named Mrs. Deedle to go back to the house with her, as she suspected something was the matter.
#
#
# 74
# OCR Text:
# d On reaching the house they heard a splashing in the d bathroom.
#
# Ground Truth:
# On reaching the house they heard a splashing in the bathroom.
#
# Model Correction:
# On reaching the house they heard a splashing in the bathroom.
#
#
# 75
# OCR Text:
# They proceeded thither, and found Mrs. 1Hibbert in the bath.
#
# Ground Truth:
# They proceeded thither, and found Mrs. Hibbert in the bath.
#
# Model Correction:
# They proceeded thither, and found Mrs. Hibbert in the bath.
#
#
# 76
# OCR Text:
# They asked her where the chil i 'dren were, and Mrs. Hibbert replied, " I have dro wned | l them, I don't think they are dead, as they are quite warns."
#
# Ground Truth:
# They asked her where the children were, and Mrs. Hibbert replied, "I have drowned them. I don't think they are dead, as they are quite warm."
#
# Model Correction:
# They asked her where the children were, and Mrs. Hibbert replied, "I have drowned them, I don't think they are dead, as they are quite warm."
#
#
# 77
# OCR Text:
# She took theum into a bedroom where the two al children were found lying quite naked on the bed, and h although the bodies were warm they were perfectly h dead.
#
# Ground Truth:
# She took them into a bedroom where the two children were found lying quite naked on the bed, and although the bodies were warm they were perfectly dead.
#
# Model Correction:
# She took them into a bedroom where the two children were found lying quite naked on the bed, and although the bodies were warm they were perfectly dead.
#
#
# 78
# OCR Text:
# Airs. Hibbert also told thetm she had been t trying to drown herself in the bath for the last half |S hour.
#
# Ground Truth:
# Mrs. Hibbert also told them she had been trying to drown herself in the bath for the last half hour.
#
# Model Correction:
# Mrs. Hibbert also told the them she had been trying to drown herself in the bath for the last half hour.
#
#
# 79
# OCR Text:
# On receipt of this information Inspector Smith went down to the house and made an examination of h- the premises.
#
# Ground Truth:
# On receipt of this information Inspector smith went down to the house and made an examination of the premises.
#
# Model Correction:
# On receipt of this information Inspector Smith went down to the house and made an examination of the premises.
#
#
# 80
# OCR Text:
# He found the two children lying dead St on the bed.
#
# Ground Truth:
# He found the two children lying dead on the bed.
#
# Model Correction:
# He found the two children lying dead on the bed.
#
#
# 81
# OCR Text:
# A piece of paper containing a few almost o illegible sentences was laid on the body of the eldest child,
#
# Ground Truth:
# A piece of paper containing a few almost illegible sentences was laid on the body of the eldest child.
#
# Model Correction:
# A piece of paper containing a few almost illegible sentences was laid on the body of the eldest child.
#
#
# 82
# OCR Text:
# MIDDLESEX SESSIONS. Sl~~s/ - . - - -
#
# Ground Truth:
# MIDDLESEX SESSIONS.
#
# Model Correction:
# MIDDLESEX SESSIONS.
#
#
# 83
# OCR Text:
# T ,,1 PAr.IsH PiosECUTLONS AT THEWxi' END ,
#
# Ground Truth:
# PARISH PROSECUTIONS AT THE WEST END.
#
# Model Correction:
# PARISH PROSECUTIONS AT THE WEST END.
#
#
# 84
# OCR Text:
# -Julei do Bodt, a Frenchman, was indicted for keeping a dis- orderly house in the parish of St. Marylebone.
#
# Ground Truth:
# -Jules de Bodt, a Frenchman, was indicted for keeping a disorderly house in the parish of St. Marylebone.
#
# Model Correction:
# -Julius de Bodt, a Frenchman, was indicted for keeping a disorderly house in the parish of St. Marylebone.
#
#
# 85
# OCR Text:
# From the statement of Mr. Poland it appeared that for some years past the prisoner was the occupier of a house, No. 12, Market-place, Oxford-street, on the site of the old Oxford-street Market, and complaints were made to the vestry as to the manner in which this house was conducted.
#
# Ground Truth:
# From the statement of Mr. Poland it appeared that for some years past the prisoner was the occupier of a house, No. 12, Market-place, Oxford-street, on the site of the old Oxford-street Market, and complaints were made to the vestry as to the manner in which this house was conducted.
#
# Model Correction:
# From the statement of Mr. Poland it appeared that for some years past the prisoner was the occupier of a house, No. 12, Market-place, Oxford-street, on the site of the old Oxford-street Market, and complaints were made to the vestry as to the manner in which this house was conducted.
#
#
# 86
# OCR Text:
# On the outside of the house was written up "Jules de Bodt, cabinetmaker," and also " Madame de Bodt, French laundry," and in con- sequence of the complaints which were made as to the conduct of the house an officer ofthe vestry in October, 1881, called upon the prisoner and warned him to die- continue the practice of what he was then doing, for I if it was continued the vestry would be forced to take proceedings and put the law in force against him.
#
# Ground Truth:
# On the outside of the house was written up "Jules de Bodt, cabinetmaker," and also ''Madame de Bodt, French laundry," and in consequence of the complaints which were made as to the conduct of the house an officer of the vestry in October, 1881, called upon the prisoner and warned him to discontinue the practice of what he was then doing, for if it was continued the vestry would be forced to take proceedings and put the law in force against him.
#
# Model Correction:
# On the outside of the house was written up "Jules de Bodt, cabinetmaker," and also "Madame de Bodt, French laundry," and in consequence of the complaints which were made as to the conduct of the house an officer of the vestry in October, 1881, called upon the prisoner and warned him to discontinue the practice of what he was then doing, for if it was continued the vestry would be forced to take proceedings and put the law in force against him.
#
#
# 87
# OCR Text:
# I Subsequently, howvever, renewed complaints were made by the inhabitants as to the nuisance they ex- perienced as to what was going on at this house, which was frequented by low characters of French nationality, who brought men home with them at all hours, and in the warm season the inmates of the house were very indelicately attired, and as the windows in the upper part of the house were thrown wide open, the inhabitants occupying houses on the opposite side were greatly scandalised thereby, and one of them, a professor of music, who received pupils, was compelled to keep his blinds down throughout the day in consequence of the scenes that were going on.
#
# Ground Truth:
# Subsequently, however, renewed complaints were made by the inhabitants as to the nuisance they experienced as to what was going on at this house, which was frequented by low characters of French nationality, who brought men home with them at all hours, and in the warm season the inmates of the house ware very indelicately attired, and as the windows in the upper part of the house were thrown wide open, the inhabitants occupying houses on the opposite side were greatly scandalized thereby, and one of them, a professor of music, who received pupils, was compelled to keep his blinds down throughout the day in consequence of the scenes that were going on.
#
# Model Correction:
# Subsequently, however, renewed complaints were made by the inhabitants as to the nuisance they experienced as to what was going on at this house, which was frequented by low characters of French nationality, who brought men home with them at all hours, and in the warm season the inmates of the house were very indelicately attired, and as the windows in the upper part of the house were thrown wide open, the inhabitants occupying houses on the opposite side were greatly scandalised thereby, and one of them, a professor of music, who received pupils, was compelled to keep his blinds down throughout the day in consequence of the scenes that were going on.
#
#
# 88
# OCR Text:
# i Witnesses having been called in support of this state. ment, the jury foundthe prisoner guilty.
#
# Ground Truth:
# Witnesses having been called in support of this statement, the jury found the prisoner guilty.
#
# Model Correction:
# Witnesses having been called in support of this statement, the jury found the prisoner guilty.
#
#
# 89
# OCR Text:
# Thelearned judge ordered him to pay a fine of �50, and to enter into his own recognisances of �50, and to find two sureties of �25 each, or one surety of �50, for his good behaviour for twelve months.
#
# Ground Truth:
# The learned judge ordered him to pay a fine of £50, and to enter into his own recognisances of £50, and to find two sureties of £25 each, or one surety of £50, for his good behaviour for twelve months.
#
# Model Correction:
# The learned judge ordered him to pay a fine of £50, and to enter into his own recognisances of £50, and to find two sureties of £25 each, or one surety of £50, for his good behaviour for twelve months.
#
#
# 90
# OCR Text:
# FRAUDS upoN BULDERS.
#
# Ground Truth:
# FRAUDS UPON BUILDERS.
#
# Model Correction:
# FRAUDS UPON BUILDERS.
#
#
# 91
# OCR Text:
# -Edwin Samuel Boosey, thirty-seven, surveyor, was indicted for having ob- tained by false pretences various sums of money from divers persons with intent, in ach case, to defraud.
#
# Ground Truth:
# -Edwin Samuel Boosey, thirty-seven, surveyor, was indicted for having obtained by false pretences various sums of money from divers persons with intent, in each case, to defraud.
#
# Model Correction:
# -Edwin Samuel Boosey, thirty-seven, surveyor, was indicted for having obtained by false pretences various sums of money from divers persons with intent, in each case, to defraud.
#
#
# 92
# OCR Text:
# From the statement of the learned counsel on behalf of the Treasury, it appeared that a most extraordinary t system of fraud had been practised, there being no . less than six prosecutors.
#
# Ground Truth:
# From the statement of the learned counsel on behalf of the Treasury, it appeared that a most extraordinary system of fraud had been practised, there being no loss than six prosecutors.
#
# Model Correction:
# From the statement of the learned counsel on behalf of the Treasury, it appeared that a most extraordinary system of fraud had been practised, there being no less than six prosecutors.
#
#
# 93
# OCR Text:
# One of those was a Mr. e George Burrows, a builder, residing at Chingford, who saw an advertisement asking for tenders for the finishing of four small houses on the Chingford Station Estate.
#
# Ground Truth:
# One of these was a Mr. George Burrows, a builder, residing at Chingford, who saw an advertisement asking for tenders for the finishing of four small houses on the Chingford Station Estate.
#
# Model Correction:
# One of those was a Mr. George Burrows, a builder, residing at Chingford, who saw an advertisement asking for tenders for the finishing of four small houses on the Chingford Station Estate.
#
#
# 94
# OCR Text:
# M r. Burrows called at the address 3 named, Langbam-place, Regent-street, where he saw i the prisoner, who spoke to him regarding a letter which r he had addressed to him.
#
# Ground Truth:
# Mr. Burrows called at the address named, Langham-place, Regent-street, where he saw the prisoner, who spoke to him regarding a letter which he had addressed to him.
#
# Model Correction:
# Mr. Burrows called at the address named, Langham-place, Regent-street, where he saw the prisoner, who spoke to him regarding a letter which he had addressed to him.
#
#
# 95
# OCR Text:
# The prisoner then said that 3 he would supply plans and specifications, but would first require a deposit of two guineas, which, in the event of his tender not being accepted, would be returned.
#
# Ground Truth:
# The prisoner then said that he would supply plans and specifications, but would first require a deposit of two guineas, which, in the event of his tender not being accepted, would be returned.
#
# Model Correction:
# The prisoner then said that he would supply plans and specifications, but would first require a deposit of two guineas, which, in the event of his tender not being accepted, would be returned.
#
#
# 96
# OCR Text:
# Mr. Burrows then banded that sum over to the prisoner, who gave him the plans and specifi- cations.
#
# Ground Truth:
# Mr. Burrows then handed that sum over to the prisoner, who gave him the plans and specifications.
#
# Model Correction:
# Mr. Burrows then handed that sum over to the prisoner, who gave him the plans and specifications.
#
#
# 97
# OCR Text:
# Mr. Burrows, making sure that he would t have the completion of the job, went down to look at the carcases of the houses, when he found that the plans were extremely faulty and erroneous, there D being now bow windows in them, and it was evident that they had not been prepared from a view of the houses.
#
# Ground Truth:
# Mr. Burrows, making sure that he would have the completion of the job, went down to look at the carcases of the houses, when he found that the plans were extremely faulty and erroneous, there being now bow windows in them, and it was evident that they had not been prepared from a view of the houses.
#
# Model Correction:
# Mr. Burrows, making sure that he would have the completion of the job, went down to look at the carcases of the houses, when he found that the plans were extremely faulty and erroneous, there being now bow windows in them, and it was evident that they had not been prepared from a view of the houses.
#
#
# 98
# OCR Text:
# The prosecutor compleined of this, but could o not get one penny of his money back.
#
# Ground Truth:
# The prosecutor complained of this, but could not get one penny of his money back.
#
# Model Correction:
# The prosecutor complained of this, but could not get one penny of his money back.
#
#
# 99
# OCR Text:
# The other e cases were of a similar character.
#
# Ground Truth:
# The other cases were of a similar character.
#
# Model Correction:
# The other cases were of a similar character.
#
#
# 100
# OCR Text:
# The jury, without r. retiring, returned a verdict of guilty.
#
# Ground Truth:
# The jury, without retiring, returned a verdict of guilty.
#
# Model Correction:
# The jury, without retiring, returned a verdict of guilty.
#
#
# 101
# OCR Text:
# Detective- ) sergeant Gethen said he knew of twenty-five cases r similar to those upon which the prisoner had been 0 tried and, Sessions Warder Humphreys having proved a previous conviction on August 12th, 1878, the learned judge sentenced the prisoner to five years penal ser- vitude.
#
# Ground Truth:
# Detective- sergeant Gethen said he knew of twenty-five cases similar to those upon which the prisoner had been tried; and, Sessions Warder Humphreys having proved a previous conviction on August 12th, 1878, the learned judge sentenced the prisoner to five years penal servitude.
#
# Model Correction:
# Detective-sergeant Gethen said he knew of twenty-five cases similar to those upon which the prisoner had been tried, and, Sessions Warder Humphreys having proved a previous conviction on August 12th, 1878, the learned judge sentenced the prisoner to five years' penal servitude.
#
#
# 102
# OCR Text:
# ALLEGED ROBBERY WITH VIOLENCE.
#
# Ground Truth:
# ALLEGED ROBBERY WITH VIOLENCE.
#
# Model Correction:
# ALLEGED ROBBERY WITH VIOLENCE.
#
#
# 103
# OCR Text:
# AT the Hammersmith Polics-court James M 'Carthy, a a costermonger, and Jacob Hyams, a tailor, were finally 0 examined on the charge of being concerned in assault- 1 ing Thomas Neesom, a glazier, of Little James-street, a Bedford-row, and stealing �4 15s from him while on e board the Citizen steamboat " 1, on the occasion of e the Gaiety Rowing Club races on the 18th ult., at r Chiswick.
#
# Ground Truth:
# AT the Hammersmith Police-court James M'Carthy, a costermonger, and Jacob Hyams, a tailor, were finally examined on the charge of being concerned in assaulting Thomas Neesom, a glazier, of Little James-street, Bedford-row, and stealing £4 15s. from him while on board the Citizen steamboat "I" on the occasion of the Gaiety Rowing Club races on the 18th ult., at Chiswick.
#
# Model Correction:
# AT the Hammersmith Police-court James M'Carthy, a costermonger, and Jacob Hyams, a tailor, were finally examined on the charge of being concerned in assaulting Thomas Neesom, a glazier, of Little James-street, Bedford-row, and stealing £4 15s. from him while on board the Citizen steamboat "1, on the occasion of the Gaiety Rowing Club races on the 18th ult., at Chiswick.
#
#
# 104
# OCR Text:
# It was alleged by the prosecutor that the prisoner Hyams demanded �2 lOs., which he refused a to pay, as he had not made any bet with him,
#
# Ground Truth:
# It was alleged by the prosecutor that the prisoner Hyams demanded £2 10s., which he refused to pay, as he had not made any bet with him.
#
# Model Correction:
# It was alleged by the prosecutor that the prisoner Hyams demanded 2l. 10s., which he refused to pay, as he had not made any bet with him.
#
#
# 105
# OCR Text:
# The a prisoner then caught hold of his leg while he was on y the bridge, and said he would have his money.
#
# Ground Truth:
# The prisoner then caught hold of his leg while he was on the bridge, and said he would have his money.
#
# Model Correction:
# The prisoner then caught hold of his leg while he was on the bridge, and said he would have his money.
#
#
# 106
# OCR Text:
# r M'Carthy and other men rushed up and caught hold of , him,
#
# Ground Truth:
# M'Carthy and other men rushed up and caught hold of him.
#
# Model Correction:
# M'Carthy and other men rushed up and caught hold of him.
#
#
# 107
# OCR Text:
# He got away down into the stokehole, but he 0 was followed by the prisoner and a number of other V miren.
#
# Ground Truth:
# He got away down into the stokehole, but he was followed by the prisoner and a number of other men.
#
# Model Correction:
# He got away down into the stokehole, but he was followed by the prisoner and a number of other women.
#
#
# 108
# OCR Text:
# M'Carthy held him while Hyams rifled his 5 pockets.
#
# Ground Truth:
# M'Carthy held him while Hyams rifled his pockets.
#
# Model Correction:
# M'Carthy held him while Hyams rifled his pockets.
#
#
# 109
# OCR Text:
# Mr. Paget heard a witness on behalf of e M'Carthy, and then ordered him to be discharged.
#
# Ground Truth:
# Mr. Paget heard a witness on behalf of McCarthy, and then ordered him to be discharged.
#
# Model Correction:
# Mr. Paget heard a witness on behalf of M'Carthy, and then ordered him to be discharged.
#
#
# 110
# OCR Text:
# 0 He committed the other prisoner for trial, allowing bail.
#
# Ground Truth:
# He committed the other prisoner for trial, allowing bail.
#
# Model Correction:
# He committed the other prisoner for trial, allowing bail.
#
#
# 111
# OCR Text:
# DEATH FROM LEAD PoiSONING.
#
# Ground Truth:
# DEATH FROM LEAD POISONING.
#
# Model Correction:
# DEATH FROM LEAD POISONING.
#
#
# 112
# OCR Text:
# 7 ON Saturday Dr. Macdonald, M.P., held an inquiry at the Vestry Hall, Church-row, Bethnal Green, 9 respecting the death of Kathleen King, aged forty, ? the wife of William King, a labourer, of 43, Half r Nichol-street, Bethnal Green, who died on Wednes- a day.
#
# Ground Truth:
# ON Saturday Dr. Macdonald, M.P., held an inquiry at the Vestry Hall, Church-row, Bethnal Green, respecting the death of Kathleen King, aged forty, the wife of William King, a labourer, of 43, Half Nichol-street, Bethnal Green, who died on Wednesday.
#
# Model Correction:
# ON Saturday Dr. Macdonald, M.P., held an inquiry at the Vestry Hall, Church-row, Bethnal Green, respecting the death of Kathleen King, aged forty, the wife of William King, a labourer, of 43, Half Nichol-street, Bethnal Green, who died on Wednesday.
#
#
# 113
# OCR Text:
# Annie Hockins deposed that deceased worked Vi at Grace's Lead Works, Bethnal Green-road, and s lodged with her.
#
# Ground Truth:
# Annie Hockins deposed that deceased worked at Grace's Lead Works, Bethnal Green-road, and lodged with her.
#
# Model Correction:
# Annie Hockins deposed that deceased worked at Grace's Lead Works, Bethnal Green-road, and lodged with her.
#
#
# 114
# OCR Text:
# Some weeks ago deceased was in a the hospital, suffering from the effects of lead poison- ing.
#
# Ground Truth:
# Some weeks ago deceased was in the hospital, suffering from the effects of lead poisoning.
#
# Model Correction:
# ...
#
# Ground Truth:
# A trial has recently taken place in Corsica for one of those frequent murders, the result of ancient fends, for which that country is so deplorably remarkable.
#
# Model Correction:
# A trial has recently taken place in Corsica for one of those frequent murders, the result of ancient vendettas, for which that country is so deplorably remarkable.
#
#
# 2754
# OCR Text:
# 'rhii liames of the prisoners ni re Allassiliuiss Niilui anil .IJau Griji. 'rite bollowing was the sibstanci of ex id(cn a-ailst tbem n- Oil the 16th of April, 1833, J. Ferri, J. Iucioni, Nicodimnits and P'aul Autoniarcld, s(ized sonke sbieep which were founda trespiassinig upo10 (tie lands of th Autornarcli, and n hich belo ogeil to a family called Nico lai, vithi whom they had been for a lIog tint varianee.
#
# Ground Truth:
# The names of the prisoners were Marsilius Nicolai and Jacque Grigi The following was the substance of evidence against them" On the 18th of April, 1833, J. Ferri, J. Lucioni, Nicodemus and Paul Automarchi, seized some sheep which were found trespassing upon the lands of the Automarchi, and which belonged to a family called Nicolai, with whom they had been for a long time a variance.
#
# Model Correction:
# The names of the prisoners are Alessandro Nili and Giovanni Grilli, following was the substance of evidence against them on the 16th of April, 1833, J. Ferri, J. Nicodini, Nicodini and Paul Autonariold, seized some sheep which were found trespassing upon the lands of the Autonariold, and which belonged to a family called Nico lai, with whom they had been for a long time in variance.
#
#
# 2755
# OCR Text:
# As they were trivinlg the sheep to tl pound, they etme about noon to a part of tb road called Reposatajo, when they were suddeuiv a sailed by a shower of muslket bails, aimed at TSlent b seven or eight illdividuals, amongst whoill were Alarsilil Nicolai au1(1 Jacques Grigi.
#
# Ground Truth:
# As they were driving the sheep to the pound, they came about noon to a part of the road called Reposatajo, when they were suddenly as sailed by a shower of musket balls, aimed at then b seven or eight individuals, amongst whom were Marsilius Nicolai and Jacques Grigi.
#
# Model Correction:
# As they were driving the sheep to the pound, they came about noon to a part of the road called Reposadajo, when they were suddenly assailed by a shower of musket balls, aimed at them by seven or eight individuals, amongst whom were Marcelin Nicolai and Jacques Grigi.
#
#
# 2756
# OCR Text:
# Ferdi and Nicedcllus Auts marchi were lilled on the spot, and Luueciolui, iho re.uivi two balls, one in tile breast and the other in the rigi eye, expired a few hollurs after.
#
# Ground Truth:
# Ferri and Nicodemus Auto marchi were killed on the spot, and Luccioni, who receive two balls, one in the breast and the other in the right eye, expired a few hours after.
#
# Model Correction:
# Ferdinand and Nicolas Auts marchi were filled on the spot, and Lucien, the receiver two balls, one in the breast and the other in the right eye, expired a few hours after.
#
#
# 2757
# OCR Text:
# Paul Automareli, thoug severely wounded, succeeded in making his escape.
#
# Ground Truth:
# Paul Automarchi, though severely wounded, succeeded in making his escape.
#
# Model Correction:
# Paul Automarli, though severely wounded, succeeded in making his escape.
#
#
# 2758
# OCR Text:
# Paul Automarchil deposed that he recognised Marsiliu Nicolai amongst the assassins, and that it was lie 10ht fired at him.
#
# Ground Truth:
# Paul Automarchi deposed that he recognized Marsilius Nicolai amongst the assassins, and that it was he who fired at him.
#
# Model Correction:
# Paul Automarchi deposed that he recognised Marsiliu Nicolai amongst the assassins, and that it was he who fired at him.
#
#
# 2759
# OCR Text:
# Other witnesses declared that, immnedi- ately before dyitg, Luccioni had alimried that Marsiliu! Nicolai was one of the murderers.
#
# Ground Truth:
# Other witnesses declared that, immediately before dying, Luccioni had affirmed that Marsilius Nicolai was one of the murderers.
#
# Model Correction:
# Other witnesses declared that, immediately before dying, Luccioni had alleged that Marsili Nicolai was one of the murderers.
#
#
# 2760
# OCR Text:
# Tibe icxt witnesl; was John Baptist Luccioni, the father of on0 of the vic- tilis.
#
# Ground Truth:
# The next witness was John Baptist Luccioni, the father of one of the victims.
#
# Model Correction:
# The next witness was John Baptist Luccioni, the father of one of the victims.
#
#
# 2761
# OCR Text:
# Being asked by the President, at the desire of the prisoner, if lie ivere not his enemy, lie turned towards Ni- colai, and, nsith the ulost impassioned gestures and tone of voice, ttus addressed him, " 0, Marsilius, you say I am11 youre enemy, but ale you not Mlarsilius Es it not to you aud )our brothers that we owe all our misfortunes ? l3ave you not ravaged our fields, tooted up our olive- trees, killed our cattle, besiegefd our houses, and ruined our faniilies ? Is it not to you that I owe the death of . brother, a brothler-in,litv, two nephews, and a seto DI, you not knowv Ste ?-look me full in the facel I "now you well uim are Marsilius !"
#
# Ground Truth:
# Being asked by the President, at the desire of the prisoner, if he were not his enemy, he turned towards Nicolai, and, with the most impassioned gestures and tone of voice, thus addressed him, "O, Marsilius, you say I am your enemy, but are you not Marsilius? Is it not to you and your brothers that we owe all our misfortunes? Have you not ravaged our fields, rooted up our olive trees, killed our cattle, besieged our houses, and ruined our families? Is it not to you that I owe the death of a brother, a brother-in-law, two nephews, and a son? Do, you not know me? -look me full in the face? I know you well, you are Marsilius!"
#
# Model Correction:
# Being asked by the President, at the desire of the prisoner, if he were not his enemy, he turned towards Nicolas, and, with the most impassioned gestures and tone of voice, thus addressed him, "0, Marsilius, you say I am your enemy, but are you not Marsilius? Is it not to you and your brothers that we owe all our misfortunes? Have you not ravaged our fields, cut down our olive-trees, killed our cattle, besieged our houses, and ruined our families? Is it not to you that I owe the death of a brother, a brother-in-law, two nephews, and a son? Do you not know me?-look me full in the face-I now you well, and are Marsilius!"
#
#
# 2762
# OCR Text:
# This apostrophe ,,rodueed a plofound effect, bothi upon the prisoner arc;t the audi- ence.
#
# Ground Truth:
# This apostrophe produced a profound effect, both upon the prisoner and the audience.
#
# Model Correction:
# This apostrophe produced a profound effect, both upon the prisoner and the audience.
#
#
# 2763
# OCR Text:
# The Jury acquitted Grigi, but ftwd dMarsilius Ni- colai guilty of nturder, and tile Cov:t sentenced bins to hard labour for life at the hulks.
#
# Ground Truth:
# The Jury acquitted Grigi, but found Marsilius Nicolai guilty of murder, and the Court sentenced him to hard labour for life at the bulks.
#
# Model Correction:
# The Jury acquitted Grigi, but found Darsilius Nicolai guilty of murder, and the Court sentenced him to hard labour for life at the hulks.
#
#
# 2764
# OCR Text:
# LAW NOTICES.
#
# Ground Truth:
# LAW NOTICES.
#
# Model Correction:
# LAW NOTICES.
#
#
# 2765
# OCR Text:
# -TFis DAY.
#
# Ground Truth:
# -THIS DAY.
#
# Model Correction:
# -THIS DAY.
#
#
# 2766
# OCR Text:
# COURT OF FHANC1'RV, LINCOLN'S INN.
#
# Ground Truth:
# COURT OF CHANCERY, LINCOLN'S INN.
#
# Model Correction:
# COURT OF CHANCERY, LINCOLN'S INN.
#
#
# 2767
# OCR Text:
# Sittings at ten,
#
# Ground Truth:
# Sittings at ten.
#
# Model Correction:
# Sittings at ten.
#
#
# 2768
# OCR Text:
# Towlyn T Reynolds, motion 6ly order-Ixparte Allel. petition by Older.
#
# Ground Truth:
# Tamlyn v Reynolds, motion by order-Exparte Allen, petition by order.
#
# Model Correction:
# Townley Reynolds, motion for order-in-chambers, allege petition by older.
#
#
# 2769
# OCR Text:
# Motions continued.
#
# Ground Truth:
# Motions continued.
#
# Model Correction:
# Motions continued.
#
#
# 2770
# OCR Text:
# VICE CHANCELLOR'S CO-RT, JAINCOLN'S INN,
#
# Ground Truth:
# VICE CHANCELLOR'S COURT, LINCOLN'S INN.
#
# Model Correction:
# VICE CHANCELLOR'S COURT, LINCOLN'S INN.
#
#
# 2771
# OCR Text:
# Sittings at tell.
#
# Ground Truth:
# Sittings at ten.
#
# Model Correction:
# Sittings at Wells.
#
#
# 2772
# OCR Text:
# Wlaresn v Burton, motion by order-Taylor v Fieldes, ditto- Attornley-Gieneral v Per~lla paMt lteard-Altoriie)G( ejirai v Stewr a rt, -t hesrI-Sitestt v sherratt. petition by order-Alloop v Torwgood. petitlon by o0','r-tLi bolld v llurant. cause by order- Spicerstr v Whis , by order-('olley v toiley. petition by order
#
# Ground Truth:
# Warren v Burton, motion by order-Taylor Fieldes, ditto-Attorney-General v Pearson, part heard-Attorney-General v Stew art, part heard-Sherratt v Sherratt, petition by order-Allsop v Towgood, petition by order-Raybould v Durant, cause by order-Spicer Whitwell, by order-Colley v Colley, petition by order.
#
# Model Correction:
# Warren v Burton, motion by order-Taylor v Fieldes, ditto-Attorney-General v Perkins, post limine-Attorney-General v Stewart, ditto-Attorney-General v Sherratt, petition by order-Allopp v Torwood, petition by order-Bold v Hurant, cause by order-Spicer v Wilde, by order-Colley v Colley, petition by order
#
#
# 2773
# OCR Text:
# -In re Dovenby iHosyitel, ditto-leigoC v Hudsontexceptiolls, part heardi-Muagoroe v iNeu ten, 1lia-Ne~tvll~l V West, deinurrer- Kelatlawr v Gal ay-ititto v ditto -;Morgoti} v It1 ell.
#
# Ground Truth:
# -In re Dovenby Hospital, ditto-Meagoe v Hodson exceptions, part heard-Musgrove v Newton, plea-Newman v West, demurrer Kelshaw v Galway-Ditto v ditto-Morgan v Howell.
#
# Model Correction:
# -In re Dovenby Hospital, ditto-leave to appeal-Morgan v Hudson, excepted, part heard-Morgan v Neuten, 1871-Neuton v West, demurrer-Kelatlaw v Galway-itto v ditto -Morgan v Mell.
#
#
# 2774
# OCR Text:
# BOLLS' COURT, CHANCERY-LANE.
#
# Ground Truth:
# ROLLS' COURT, CHANCERY-LANE.
#
# Model Correction:
# BOW-STREET, CHANCERY-LANE.
#
#
# 2775
# OCR Text:
# Sitlogo at ten.
#
# Ground Truth:
# Sittings at ten.
#
# Model Correction:
# Signature at ten.
#
#
# 2776
# OCR Text:
# Nuggeridat v V'ondrufi, jiidgnenit-In re Morgan, petition- Idaendle ounsey, part he.ra-: )!e v Sha kles-Wevt v ihut- tirwortb-GreentAmy v Ituthei ham-Tunwrir s It ltlivii , exteptions- tmith v Wystt-Hiller r lliller-Stattord v Stafford-A.ttonmev.e-( neral Y Bsrimun-Pilkinigtoii v lIrighit-Ba-rfoot v Chlittv, ditt- Pratt v Tucker.
#
# Ground Truth:
# Moggeridge v Woodruff, judgment-In re Morgan, petition Majeadle v Mounsey, part heard-sayle v Shackles-West v Shuttleworth-Greenway v Rotherham-Turner v Rawlison, exceptions Smith v Wyatt-Hiller v Hiller-Stafford v Stafford-Attorney-General v Barham-Pilkington v Bright-Barfoot v Chitty, ditto Pratt v Tucker.
#
# Model Correction:
# Nugent v Vondrus, judgment-In re Morgan, petition-Hendle counsel-Morgan v Shackles-West v Shackles-Turner v Shackles-Greenamy v Hutton-Turner v Hutton-Smith v Wyst-Hiller v Hiller-Stafford v Stafford-Attorney-General-Pilkington v Bright-Barfoot v Chitty, ditto-Pratt v Tucker.
#
#
# 2777
# OCR Text:
# COURT OF KING'S BENCH.
#
# Ground Truth:
# COURT OF KING'S BENCH.
#
# Model Correction:
# COURT OF KING'S BENCH.
#
#
# 2778
# OCR Text:
# "StilIg ;t 1llt Iimu lille.
#
# Ground Truth:
# Sitting at half-past nine.
#
# Model Correction:
# Still at it and in it.
#
#
# 2779
# OCR Text:
# LOmwDON Coumsio% J3 rlt
#
# Ground Truth:
# LONDON COMMON JURIES.
#
# Model Correction:
# LONDON COURTS.
#
#
# 2780
# OCR Text:
# -DrIVr .i I Allother v Flis-Lis , 1lsttbeues-Sinipsuli v 1t rimewor-I'llithmrii anid Anotbv r N lol. nsghi andAnother-;noglt v X% zterlnia .
#
# Ground Truth:
# -Driver and Another v Ellis-Ewins v Matthews-Simpson v Crawcour-Eitherne and Another v Colnaghi and Another-Knight v Waterman.
#
# Model Correction:
# -Dr. M'Cullagh v. Lisle's Trustees-Simpson v. M'Cullagh and Another-Nagle v. Ireland and Another.
#
#
# 2781
# OCR Text:
# COlU'it OP( , (IM'tO: Pt- 1.t
#
# Ground Truth:
# COURT OF COMMON PLEAS.
#
# Model Correction:
# COURT OF CRIMINAL SESSIONS.
#
#
# 2782
# OCR Text:
# Sitilg, o: halt ps'' orie.
#
# Ground Truth:
# Sittings at half past nine.
#
# Model Correction:
# Singing, or half-pence or apples.
#
#
# 2783
# OCR Text:
# LONDtON CoMMtoV J( hi K-S:k-nL; it % :ciueim -Pawrnlger v Brooiten-Shirley v Juli,'oiJ-Wt I< 1, II SI II .Stp500 1 It'S.
#
# Ground Truth:
# LONDON COMMON JURIES -Salmon v Cranston-Passenger v Brookes-Shirley v Jacobs-Wise v Downes Simpson v Russ.
#
# Model Correction:
# LONDON COMMON PLEAS: -Shirley v Broomfield-Julius v Julius-Watson v. Watson-£500.
#
#
# 2784
# OCR Text:
# Thll tue 1 lmrt of tE xi hluler Mll- jonrned Testerday
#
# Ground Truth:
# The Court of Exchequer adjourned yesterday.
#
# Model Correction:
# THE TRIAL OF THE EX-CHANCELLOR.
#
#
# 2785
# OCR Text:
# the iiljiII , I I I Ct r t t ing', ltteiu h, standing over tillt extterni, si t 1t (i' IV vtiallies, Ilie in Mliddlesex, tind line tli toil ,; ti til,
#
# Ground Truth:
# The business in the Court of King's Bench, standing over till next term, consist of # eighteen causes, nine in Middlesex, and nine in London.
#
# Model Correction:
# The prisoner, a young man of respectable appearance, was charged with stealing a quantity of valuable goods, the property of Messrs. Harrods, the well-known West-end shopkeepers, and also with receiving the same, knowing them to have been stolen.
#
#
# 2786
# OCR Text:
# I Ourlt (If G tmmoll I%'a there lsairearrof, ,'%i l -t, ; I ill' j IU Nd6ileV's, .4llt toCt) special and comnmlion llI U) ci11t;,w I'mdmi
#
# Ground Truth:
# In the Court of Common Pleas there is an arrear of seven special jury causes in Middlesex, and twenty special and common jury causes in London.
#
# Model Correction:
# Our lord (Grosvenor) said there was no evidence of, or charge of, fraud, and the commissioners' special and common-seal were not in force.
#
#
# 2787
# OCR Text:
# HANKRUVI'( V Cul'lt'lt',i X j NIilAt l iHi T
#
# Ground Truth:
# BANKRUPTCY COURT, BASINGHALL STREET.
#
# Model Correction:
# HANKRUVI'S CUTICLE.
#
#
# 2788
# OCR Text:
# Before Mr. Cornniiisi11cr F \ e. -t 11111 Hig t iilil'ertIIl' street, liightsbridge, baker, at till hilc iell l .belees l thurI nett, of 'TIteihtsnat-treet, Fitzroy 3kllle, c le'iplate-pi''1tcr, at Iteven ai journtd eiaminatioli
#
# Ground Truth:
# Before Mr. Commissioner FANE-Stephen King, of Kinnerton street, Knightsbridge, baker, at ten choice of assignees-John Banett, of Tottenham-street, Fitzroy square, copperplate-printer, at eleven; adjourned examination.
#
# Model Correction:
# Before Mr. Common serjeant, at the Westminster police-court, Charles Higgins, of 11, Hunt-street, Kensington, baker, and Thomas Matthews, of 10, Thistle-street, Fitzroy-square, clerk in the public service, were charged at the instance of Inspector Woolry, of the Criminal Investigation department, with being concerned together in a conspiracy to defraud the Post-office.
#
#
# 2789
# OCR Text:
# before ir. t.oii'l -sInner 111i LROVI'.
#
# Ground Truth:
# Before Mr. Commissioner HOLROYD.
#
# Model Correction:
# He was remanded for a week.
#
#
# 2790
# OCR Text:
# - 11. it. EI wrletoiul if ('h ales- street. Trevor-squuare, llr inptI l I'tIltrblit, It till tijoiullriledl xanminatirn--Stephlieson ,,,,d BtillI (t f (iret O rniuid street, Queen-square. aeycvori, i Ieill CI . l IVJlrllil I illiioll
#
# Ground Truth:
# -H. D. Eggleton, of Charles street, Trevor-square, Brompton, coal-merchant, at two adjourned examination-Stephenson and Blunt, of Great Ormond-street, Queen-square, surveyors, at twelve, adjourned examination.
#
# Model Correction:
# -J. H. ELLIOTT, 1, Caledonian-street, Trevor-square, W. C. H. STEPHENSON and W. BILLINGTON, 1, Great Queen-street, Westminster, solicitors.
#
#
# 2791
# OCR Text:
# Ov THE eitrtoU%1, FlIme
#
# Ground Truth:
# ON THE GROUND FLOOR.
#
# Model Correction:
# OF THE CIRCUIT COURT, FLINTSHIRE.
#
#
# 2792
# OCR Text:
# rt-111 H1,1rs hiill'S btih rUit(i at elvren; a reditors to ineet thleaycgineew .
#
# Ground Truth:
# -In Henry Kain's bankruptcy, at eleven; creditors to meet the assignees.
#
# Model Correction:
# The prisoner's wife was in the house, and a red-hot iron was placed in her mouth, and the engine was put in motion.
